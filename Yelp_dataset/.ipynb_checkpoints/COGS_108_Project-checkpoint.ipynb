# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # First, we will load in the datasets we are using.

# %%
# Business data with location, name, id, number of reviews, Yelp rating, categories, hours, and is open
bus_df = pd.read_json('yelp_academic_dataset_business.json', lines=True)
bus_df
# Out:
#                    business_id                       name  \
# 0       f9NumwFMBDn751xgFiRbNA   The Range At Lake Norman
# 1       Yzvjg0SayhoZgCljUJRF9Q          Carlos Santo, NMD
# 2       XNoUzKckATkOD1hP6vghZg                    Felinus
# 3       6OAZjbxqM5ol29BuHsil3w       Nevada House of Hose
# 4       51M2Kk903DFYI6gnB5I6SQ    USE MY GUY SERVICES LLC
# ...                        ...                        ...
# 209388  9Q0fPWAjUweoFDk0kafuzQ                Nishi Sushi
# 209389  PotiAhtDMYMNsJCzV0oLAw                    Walmart
# 209390  SYa2j1boLF8DcGVOYfHPcA                  Five Guys
# 209391  RSSIsgO00OuWQTRoITacpA  Indian Trail Dog Training
# 209392  tOcYmewXFhQeZh3V42ymwg                  Kudlow Ye
#
#                                 address             city state postal_code  \
# 0                       10913 Bailey Rd        Cornelius    NC       28031
# 1             8880 E Via Linda, Ste 107       Scottsdale    AZ       85258
# 2                 3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4
# 3                        1015 Sharp Cir  North Las Vegas    NV       89030
# 4                    4827 E Downing Cir             Mesa    AZ       85205
# ...                                 ...              ...   ...         ...
# 209388                 9750 Weston Road          Vaughan    ON     L4H 2P2
# 209389              3240 Wilkinson Blvd        Charlotte    NC       28208
# 209390          7014-590 E Camelback Rd       Scottsdale    AZ       85251
# 209391                                      Indian Trail    NC       28079
# 209392  21 St Clair Avenue E, Suite 401          Toronto    ON     M4T 1L9
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       35.462724  -80.852612    3.5            36        1
# 1       33.569404 -111.890264    5.0             4        1
# 2       45.479984  -73.580070    5.0             5        1
# 3       36.219728 -115.127725    2.5             3        0
# 4       33.428065 -111.726648    4.5            26        1
# ...           ...         ...    ...           ...      ...
# 209388  43.838555  -79.559823    4.0             5        0
# 209389  35.226307  -80.893539    2.0            13        0
# 209390  33.504062 -111.929431    3.5            97        1
# 209391  35.101965  -80.599385    5.0             3        1
# 209392  43.688214  -79.392756    5.0             3        1
#
#                                                attributes  \
# 0       {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1       {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 2                                                    None
# 3       {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 4       {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# ...                                                   ...
# 209388  {'Ambience': '{'romantic': False, 'intimate': ...
# 209389  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 209390  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 209391                                               None
# 209392                                               None
#
#                                                categories  \
# 0       Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1       Health & Medical, Fitness & Instruction, Yoga,...
# 2                        Pets, Pet Services, Pet Groomers
# 3       Hardware Stores, Home Services, Building Suppl...
# 4       Home Services, Plumbing, Electricians, Handyma...
# ...                                                   ...
# 209388                  Japanese, Sushi Bars, Restaurants
# 209389  Department Stores, Food, Mobile Phones, Fashio...
# 209390  American (New), Food, Burgers, Restaurants, Fa...
# 209391                   Pet Services, Pet Training, Pets
# 209392  Tax Services, Professional Services, Accountan...
#
#                                                     hours
# 0       {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1                                                    None
# 2                                                    None
# 3       {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 4       {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...
# ...                                                   ...
# 209388  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209389                                               None
# 209390  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209391  {'Monday': '0:0-0:0', 'Tuesday': '7:0-19:0', '...
# 209392  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
#
# [209393 rows x 14 columns]

# %%
# Not necessary
check_df = pd.read_json('yelp_academic_dataset_checkin.json', lines=True)
check_df
# Out:
#                    business_id  \
# 0       --1UhMGODdWsrMastO9DZw
# 1       --6MefnULPED_I942VcFNA
# 2       --7zmmkVg-IMGaXbuVd0SQ
# 3       --8LPVSo5i0Oo61X01sV9A
# 4       --9QQLMTbFzLJ_oT-ON3Xw
# ...                        ...
# 175182  zzvlwkcNR1CCqOPXwuvz2A
# 175183  zzwaS0xn1MVEPEf0hNLjew
# 175184  zzwhN7x37nyjP0ZM8oiHmw
# 175185  zzwicjPC9g246MK2M1ZFBA
# 175186  zzzaIBwimxVej4tY6qFOUQ
#
#                                                      date
# 0       2016-04-26 19:49:16, 2016-08-30 18:36:57, 2016...
# 1       2011-06-04 18:22:23, 2011-07-23 23:51:33, 2012...
# 2       2014-12-29 19:25:50, 2015-01-17 01:49:14, 2015...
# 3                                     2016-07-08 16:43:30
# 4       2010-06-26 17:39:07, 2010-08-01 20:06:21, 2010...
# ...                                                   ...
# 175182  2017-05-06 20:05:15, 2017-05-12 22:37:03, 2017...
# 175183  2010-02-16 02:09:56, 2010-07-05 05:40:48, 2010...
# 175184  2016-03-06 13:27:02, 2016-03-09 00:41:53, 2016...
# 175185  2012-09-22 00:26:15, 2012-09-23 20:12:00, 2012...
# 175186  2012-10-12 16:26:35, 2012-10-19 19:31:14, 2012...
#
# [175187 rows x 2 columns]

# %%
#Population data
pop_df = pd.read_csv('pop-by-zip-code.csv',dtype={'zip_code':'str'})
pop_df
# Out:
#       zip_code  y-2016  y-2015  y-2014  y-2013  y-2012  y-2011  y-2010  \
# 0        00601   17800   17982   18088   18450   18544   18533   18570
# 1        00602   39716   40260   40859   41302   41640   41930   41520
# 2        00603   51565   52408   53162   53683   54540   54475   54689
# 3        00606    6320    6331    6415    6591    6593    6386    6615
# 4        00610   27976   28328   28805   28963   29141   29111   29016
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 33115    99923       0      13      12      81      77     116      87
# 33116    99925     908     826     728     668     673     689     819
# 33117    99926    1667    1711    1622    1630    1624    1488    1460
# 33118    99927      81     123     131     111      75      67      94
# 33119    99929    2385    2365    2354    2341    2361    2321    2338
#
#        aggregate
# 0         127967
# 1         287227
# 2         374522
# 3          45251
# 4         201340
# ...          ...
# 33115        386
# 33116       5311
# 33117      11202
# 33118        682
# 33119      16465
#
# [33120 rows x 9 columns]

# %% [markdown]
# # Now, we will prepare the data for our project.

# %%
# Clean data to remove all Canadian locations. We'll be using U.S. locations for this project.
# For this, we will get the dataframe to only have cases with a 5-digit postal code.
bus_df = bus_df[bus_df['postal_code'].str.contains(r'^\d{5}$')]
bus_df
# Out:
#                    business_id                         name  \
# 0       f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman
# 1       Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD
# 3       6OAZjbxqM5ol29BuHsil3w         Nevada House of Hose
# 4       51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC
# 5       cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert
# ...                        ...                          ...
# 209385  hskVqZCPqy-omm9CHi44xQ                     Domino's
# 209386  JjcJVqhZXhP4tvOhg3fnag            Water Heater Pros
# 209389  PotiAhtDMYMNsJCzV0oLAw                      Walmart
# 209390  SYa2j1boLF8DcGVOYfHPcA                    Five Guys
# 209391  RSSIsgO00OuWQTRoITacpA    Indian Trail Dog Training
#
#                           address             city state postal_code  \
# 0                 10913 Bailey Rd        Cornelius    NC       28031
# 1       8880 E Via Linda, Ste 107       Scottsdale    AZ       85258
# 3                  1015 Sharp Cir  North Las Vegas    NV       89030
# 4              4827 E Downing Cir             Mesa    AZ       85205
# 5       1720 W Elliot Rd, Ste 105          Gilbert    AZ       85233
# ...                           ...              ...   ...         ...
# 209385      6420 Rea Rd, Suite B1        Charlotte    NC       28226
# 209386                                   Las Vegas    NV       89120
# 209389        3240 Wilkinson Blvd        Charlotte    NC       28208
# 209390    7014-590 E Camelback Rd       Scottsdale    AZ       85251
# 209391                                Indian Trail    NC       28079
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       35.462724  -80.852612    3.5            36        1
# 1       33.569404 -111.890264    5.0             4        1
# 3       36.219728 -115.127725    2.5             3        0
# 4       33.428065 -111.726648    4.5            26        1
# 5       33.350399 -111.827142    4.5            38        1
# ...           ...         ...    ...           ...      ...
# 209385  35.078538  -80.818358    2.0            16        1
# 209386  36.076977 -115.244794    5.0           217        1
# 209389  35.226307  -80.893539    2.0            13        0
# 209390  33.504062 -111.929431    3.5            97        1
# 209391  35.101965  -80.599385    5.0             3        1
#
#                                                attributes  \
# 0       {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1       {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 3       {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 4       {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 5                  {'BusinessAcceptsCreditCards': 'True'}
# ...                                                   ...
# 209385  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 209386  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 209389  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 209390  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 209391                                               None
#
#                                                categories  \
# 0       Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1       Health & Medical, Fitness & Instruction, Yoga,...
# 3       Hardware Stores, Home Services, Building Suppl...
# 4       Home Services, Plumbing, Electricians, Handyma...
# 5       Auto Repair, Automotive, Oil Change Stations, ...
# ...                                                   ...
# 209385  Restaurants, Pizza, Sandwiches, Fast Food, Chi...
# 209386  Contractors, Local Services, Appliances & Repa...
# 209389  Department Stores, Food, Mobile Phones, Fashio...
# 209390  American (New), Food, Burgers, Restaurants, Fa...
# 209391                   Pet Services, Pet Training, Pets
#
#                                                     hours
# 0       {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...
# 1                                                    None
# 3       {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...
# 4       {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...
# 5       {'Monday': '7:0-18:0', 'Tuesday': '7:0-18:0', ...
# ...                                                   ...
# 209385  {'Monday': '10:30-0:0', 'Tuesday': '10:30-0:0'...
# 209386  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...
# 209389                                               None
# 209390  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 209391  {'Monday': '0:0-0:0', 'Tuesday': '7:0-19:0', '...
#
# [153579 rows x 14 columns]

# %% [markdown]
# ## We need to find out which names need to be standardized.

# %%
# We will select the top 10 fast food chains and some extras for our analysis. But first, let's explore our dataset to
# make sure we're getting the way the names are inputted correctly. For example, Domino's Pizza is listed as just
# Domino's in this dataset.
mcd = bus_df[bus_df['name'].str.contains("McDonald")]
starb = bus_df[bus_df['name'].str.contains("Starbucks")]

#We notice that with Subway, some are called Subway Restaurants and some are just Subway. We will standardize this.
sub = bus_df[bus_df['name'].str.contains("Subway")]

bk = bus_df[bus_df['name'].str.contains("Burger King")]
tb = bus_df[bus_df['name'].str.contains("Taco Bell")]
wendys = bus_df[bus_df['name'].str.contains("Wendy")]

# Dunkin' also needs to be standardized as some are Dunkin',some are Dunkin' Donuts, some are with Baskin-Robbins.
dunkin = bus_df[bus_df['name'].str.contains("Dunkin")]

# Chick-fil-A needs to be standardized.
cfa = bus_df[bus_df['name'].str.contains("Chick-")]

# Some Domino's are just Domino's while some are Domino's Pizza. Needs to be standardized.
domino = bus_df[bus_df['name'].str.contains("Domino")]

pizza_hut = bus_df[bus_df['name'].str.contains("Pizza Hut")]

# %%
# Just for reference, this is what Dunkin' entries looked like.
bus_df[bus_df['name'].str.contains("Dunkin")]
# Out:
#                    business_id                           name  \
# 340     HccqNuvwDCrnAAM5e5lQ_w                        Dunkin'
# 533     rljaZWpdhJfrWAPT6kYb7g  Dunkin' Donuts/Baskin-Robbins
# 785     QZ-BhQotj-mSpTyse35udA                        Dunkin'
# 1053    uJIIgBmcIn-Ye-anrqK0DQ                        Dunkin'
# 3480    rd9DTyWkLAUr1z189DMj5w                        Dunkin'
# ...                        ...                            ...
# 198294  r3kFRJuy7CTxamZycndqGw                        Dunkin'
# 200523  92UwiPi_dOQfCP9dxhOeQQ                        Dunkin'
# 203264  50tjBMTlIbFBxjTRXAVZHQ                        Dunkin'
# 204663  ylLChdh7Oyx3SW8SxOTlbA                 Dunkin' Donuts
# 207689  wbVRLmGpJITCxDD20ceHWw                        Dunkin'
#
#                              address           city state postal_code  \
# 340               4125 S Eastern Ave      Las Vegas    NV       89119
# 533                  21015 Lorain Rd  Fairview Park    OH       44126
# 785                  10240 N 90th St     Scottsdale    AZ       85258
# 1053            1302 N. Prospect Ave      Champaign    IL       61820
# 3480           5029 Beatties Ford Rd      Charlotte    NC       28216
# ...                              ...            ...   ...         ...
# 198294  7430 Las Vegas Blvd, Ste 100      Las Vegas    NV       89123
# 200523        6751 E. Wilkinson Blvd        Belmont    NC       28012
# 203264    6935 N Durango Dr, Ste 150      Las Vegas    NV       89149
# 204663             411 Smithfield St     Pittsburgh    PA       15222
# 207689                   344 Rodi Rd     Penn Hills    PA       15235
#
#          latitude   longitude  stars  review_count  is_open  \
# 340     36.113742 -115.119507    2.5            76        1
# 533     41.445915  -81.853363    3.0            15        1
# 785     33.579467 -111.886979    2.5            61        1
# 1053    40.128653  -88.257411    2.0            18        1
# 3480    35.304564  -80.858557    2.0            15        1
# ...           ...         ...    ...           ...      ...
# 198294  36.054565 -115.171491    3.0           212        1
# 200523  35.252260  -81.029012    2.5            18        1
# 203264  36.285821 -115.288547    2.0           132        1
# 204663  40.439093  -79.999581    4.5             3        0
# 207689  40.458264  -79.823765    2.0            21        1
#
#                                                attributes  \
# 340     {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 533     {'OutdoorSeating': 'True', 'BusinessParking': ...
# 785     {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 1053    {'RestaurantsPriceRange2': '1', 'OutdoorSeatin...
# 3480    {'BikeParking': 'True', 'BusinessParking': '{'...
# ...                                                   ...
# 198294  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 200523  {'OutdoorSeating': 'False', 'BusinessParking':...
# 203264  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 204663  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 207689  {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#                                                categories  \
# 340                  Coffee & Tea, Donuts, Food, Bakeries
# 533     Ice Cream & Frozen Yogurt, Coffee & Tea, Donut...
# 785                            Donuts, Food, Coffee & Tea
# 1053                           Donuts, Food, Coffee & Tea
# 3480                           Coffee & Tea, Donuts, Food
# ...                                                   ...
# 198294                         Donuts, Coffee & Tea, Food
# 200523                         Food, Coffee & Tea, Donuts
# 203264                 Coffee & Tea, Bagels, Donuts, Food
# 204663                         Donuts, Food, Coffee & Tea
# 207689            Food, Coffee & Tea, Donuts, Restaurants
#
#                                                     hours
# 340     {'Monday': '5:0-18:0', 'Tuesday': '5:0-18:0', ...
# 533                                                  None
# 785     {'Monday': '4:0-21:0', 'Tuesday': '4:0-21:0', ...
# 1053    {'Monday': '5:0-19:0', 'Tuesday': '5:0-19:0', ...
# 3480    {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# ...                                                   ...
# 198294  {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# 200523  {'Monday': '5:0-22:0', 'Tuesday': '5:0-22:0', ...
# 203264  {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# 204663  {'Monday': '6:0-19:0', 'Tuesday': '6:0-19:0', ...
# 207689  {'Monday': '5:0-22:0', 'Tuesday': '5:0-22:0', ...
#
# [242 rows x 14 columns]

# %%
# Now, it's time to standardize these.

def standardize_restaurant(string):
    temp = string.lower()
    if "mcdonald" in temp:
        output = "McDonald's"
    elif "starbucks" in temp:
        output = "Starbucks"
    elif "subway" in temp:
        output = "Subway"
    elif "burger king" in temp:
        output = "Burger King"
    elif "taco bell" in temp:
        output = "Taco Bell"
    elif "wendy" in temp:
        output = "Wendy's"
    elif "dunkin" in temp:
        output = "Dunkin'"
    elif "chick-" in temp:
        output = "Chick-fil-A"
    elif "domino" in temp:
        output = "Domino's"
    elif "pizza hut" in temp:
        output = "Pizza Hut"
    else:
        output = string
    return output

# %%
bus_df['name'] = bus_df['name'].apply(standardize_restaurant)
# Out:
# /Users/rakesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Now let's see how this worked on Domino's.
bus_df[bus_df['name'].str.contains("Dunkin")]
# Out:
#                    business_id     name                       address  \
# 340     HccqNuvwDCrnAAM5e5lQ_w  Dunkin'            4125 S Eastern Ave
# 533     rljaZWpdhJfrWAPT6kYb7g  Dunkin'               21015 Lorain Rd
# 785     QZ-BhQotj-mSpTyse35udA  Dunkin'               10240 N 90th St
# 1053    uJIIgBmcIn-Ye-anrqK0DQ  Dunkin'          1302 N. Prospect Ave
# 3480    rd9DTyWkLAUr1z189DMj5w  Dunkin'         5029 Beatties Ford Rd
# ...                        ...      ...                           ...
# 198294  r3kFRJuy7CTxamZycndqGw  Dunkin'  7430 Las Vegas Blvd, Ste 100
# 200523  92UwiPi_dOQfCP9dxhOeQQ  Dunkin'        6751 E. Wilkinson Blvd
# 203264  50tjBMTlIbFBxjTRXAVZHQ  Dunkin'    6935 N Durango Dr, Ste 150
# 204663  ylLChdh7Oyx3SW8SxOTlbA  Dunkin'             411 Smithfield St
# 207689  wbVRLmGpJITCxDD20ceHWw  Dunkin'                   344 Rodi Rd
#
#                  city state postal_code   latitude   longitude  stars  \
# 340         Las Vegas    NV       89119  36.113742 -115.119507    2.5
# 533     Fairview Park    OH       44126  41.445915  -81.853363    3.0
# 785        Scottsdale    AZ       85258  33.579467 -111.886979    2.5
# 1053        Champaign    IL       61820  40.128653  -88.257411    2.0
# 3480        Charlotte    NC       28216  35.304564  -80.858557    2.0
# ...               ...   ...         ...        ...         ...    ...
# 198294      Las Vegas    NV       89123  36.054565 -115.171491    3.0
# 200523        Belmont    NC       28012  35.252260  -81.029012    2.5
# 203264      Las Vegas    NV       89149  36.285821 -115.288547    2.0
# 204663     Pittsburgh    PA       15222  40.439093  -79.999581    4.5
# 207689     Penn Hills    PA       15235  40.458264  -79.823765    2.0
#
#         review_count  is_open  \
# 340               76        1
# 533               15        1
# 785               61        1
# 1053              18        1
# 3480              15        1
# ...              ...      ...
# 198294           212        1
# 200523            18        1
# 203264           132        1
# 204663             3        0
# 207689            21        1
#
#                                                attributes  \
# 340     {'RestaurantsTakeOut': 'True', 'RestaurantsDel...
# 533     {'OutdoorSeating': 'True', 'BusinessParking': ...
# 785     {'BusinessAcceptsCreditCards': 'True', 'WiFi':...
# 1053    {'RestaurantsPriceRange2': '1', 'OutdoorSeatin...
# 3480    {'BikeParking': 'True', 'BusinessParking': '{'...
# ...                                                   ...
# 198294  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 200523  {'OutdoorSeating': 'False', 'BusinessParking':...
# 203264  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 204663  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 207689  {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#                                                categories  \
# 340                  Coffee & Tea, Donuts, Food, Bakeries
# 533     Ice Cream & Frozen Yogurt, Coffee & Tea, Donut...
# 785                            Donuts, Food, Coffee & Tea
# 1053                           Donuts, Food, Coffee & Tea
# 3480                           Coffee & Tea, Donuts, Food
# ...                                                   ...
# 198294                         Donuts, Coffee & Tea, Food
# 200523                         Food, Coffee & Tea, Donuts
# 203264                 Coffee & Tea, Bagels, Donuts, Food
# 204663                         Donuts, Food, Coffee & Tea
# 207689            Food, Coffee & Tea, Donuts, Restaurants
#
#                                                     hours
# 340     {'Monday': '5:0-18:0', 'Tuesday': '5:0-18:0', ...
# 533                                                  None
# 785     {'Monday': '4:0-21:0', 'Tuesday': '4:0-21:0', ...
# 1053    {'Monday': '5:0-19:0', 'Tuesday': '5:0-19:0', ...
# 3480    {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# ...                                                   ...
# 198294  {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# 200523  {'Monday': '5:0-22:0', 'Tuesday': '5:0-22:0', ...
# 203264  {'Monday': '5:0-21:0', 'Tuesday': '5:0-21:0', ...
# 204663  {'Monday': '6:0-19:0', 'Tuesday': '6:0-19:0', ...
# 207689  {'Monday': '5:0-22:0', 'Tuesday': '5:0-22:0', ...
#
# [242 rows x 14 columns]

# %%
# Now, let's merge the population data to include an extra parameter that could have an impact on our project.
# For our case, we will use the most recent population data we have.
new_pop_df = pop_df[['zip_code','y-2016']]
bus_df = bus_df.rename(columns={"postal_code":"zip_code"})
df = bus_df.merge(new_pop_df, how='left', on='zip_code')
df = df.rename(columns={"y-2016":"population"})
df
# Out:
#                    business_id                         name  \
# 0       f9NumwFMBDn751xgFiRbNA     The Range At Lake Norman
# 1       Yzvjg0SayhoZgCljUJRF9Q            Carlos Santo, NMD
# 2       6OAZjbxqM5ol29BuHsil3w         Nevada House of Hose
# 3       51M2Kk903DFYI6gnB5I6SQ      USE MY GUY SERVICES LLC
# 4       cKyLV5oWZJ2NudWgqs8VZw  Oasis Auto Center - Gilbert
# ...                        ...                          ...
# 153574  hskVqZCPqy-omm9CHi44xQ                     Domino's
# 153575  JjcJVqhZXhP4tvOhg3fnag            Water Heater Pros
# 153576  PotiAhtDMYMNsJCzV0oLAw                      Walmart
# 153577  SYa2j1boLF8DcGVOYfHPcA                    Five Guys
# 153578  RSSIsgO00OuWQTRoITacpA    Indian Trail Dog Training
#
#                           address             city state zip_code   latitude  \
# 0                 10913 Bailey Rd        Cornelius    NC    28031  35.462724
# 1       8880 E Via Linda, Ste 107       Scottsdale    AZ    85258  33.569404
# 2                  1015 Sharp Cir  North Las Vegas    NV    89030  36.219728
# 3              4827 E Downing Cir             Mesa    AZ    85205  33.428065
# 4       1720 W Elliot Rd, Ste 105          Gilbert    AZ    85233  33.350399
# ...                           ...              ...   ...      ...        ...
# 153574      6420 Rea Rd, Suite B1        Charlotte    NC    28226  35.078538
# 153575                                   Las Vegas    NV    89120  36.076977
# 153576        3240 Wilkinson Blvd        Charlotte    NC    28208  35.226307
# 153577    7014-590 E Camelback Rd       Scottsdale    AZ    85251  33.504062
# 153578                                Indian Trail    NC    28079  35.101965
#
#          longitude  stars  review_count  is_open  \
# 0       -80.852612    3.5            36        1
# 1      -111.890264    5.0             4        1
# 2      -115.127725    2.5             3        0
# 3      -111.726648    4.5            26        1
# 4      -111.827142    4.5            38        1
# ...            ...    ...           ...      ...
# 153574  -80.818358    2.0            16        1
# 153575 -115.244794    5.0           217        1
# 153576  -80.893539    2.0            13        0
# 153577 -111.929431    3.5            97        1
# 153578  -80.599385    5.0             3        1
#
#                                                attributes  \
# 0       {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 1       {'GoodForKids': 'True', 'ByAppointmentOnly': '...
# 2       {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 3       {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 4                  {'BusinessAcceptsCreditCards': 'True'}
# ...                                                   ...
# 153574  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 153575  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 153576  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 153577  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 153578                                               None
#
#                                                categories  \
# 0       Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 1       Health & Medical, Fitness & Instruction, Yoga,...
# 2       Hardware Stores, Home Services, Building Suppl...
# 3       Home Services, Plumbing, Electricians, Handyma...
# 4       Auto Repair, Automotive, Oil Change Stations, ...
# ...                                                   ...
# 153574  Restaurants, Pizza, Sandwiches, Fast Food, Chi...
# 153575  Contractors, Local Services, Appliances & Repa...
# 153576  Department Stores, Food, Mobile Phones, Fashio...
# 153577  American (New), Food, Burgers, Restaurants, Fa...
# 153578                   Pet Services, Pet Training, Pets
#
#                                                     hours  population
# 0       {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...     26686.0
# 1                                                    None     23933.0
# 2       {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...     47895.0
# 3       {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...     41376.0
# 4       {'Monday': '7:0-18:0', 'Tuesday': '7:0-18:0', ...     35828.0
# ...                                                   ...         ...
# 153574  {'Monday': '10:30-0:0', 'Tuesday': '10:30-0:0'...     39052.0
# 153575  {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...     24830.0
# 153576                                               None     36328.0
# 153577  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...     39867.0
# 153578  {'Monday': '0:0-0:0', 'Tuesday': '7:0-19:0', '...     34282.0
#
# [153579 rows x 15 columns]

# %%
# Now let's reduce this dataframe to just the restaurants chains we're examining.
